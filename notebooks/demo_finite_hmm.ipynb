# %% [markdown]
# # Demo: baseline HMM finito
#
# Este notebook muestra el baseline de 24 estados armonicos heredado del notebook original, ya refactorizado dentro de `src/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
elif not (PROJECT_ROOT / 'src').exists() and (PROJECT_ROOT.parent / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

EXAMPLE_SCORE = PROJECT_ROOT / 'examples' / 'example_score.musicxml'
OUTPUT_DIR = PROJECT_ROOT / 'outputs' / 'notebook_finite'

print('PROJECT_ROOT =', PROJECT_ROOT)
print('EXAMPLE_SCORE =', EXAMPLE_SCORE)
# Out:
# PROJECT_ROOT = /home/janusadamuz/Documentos/Melodies
# EXAMPLE_SCORE = /home/janusadamuz/Documentos/Melodies/examples/example_score.musicxml

# %%
from examples.generate_example_score import main as generate_example_score

generate_example_score()
# Out:
# /home/janusadamuz/miniconda3/lib/python3.13/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.1) or chardet (7.3.0)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# Partitura de ejemplo generada en: examples/example_score.musicxml

# %%
from src.data.parsing import parse_score, extract_events
from src.data.observations import build_observation_sequence
from src.models.finite_hmm import FiniteChordHMM
from src.analysis.diagnostics import summarize_finite_result

score = parse_score(EXAMPLE_SCORE)
events = extract_events(score)
observations = build_observation_sequence(events, 'pitch_class')
result = FiniteChordHMM().fit_predict(observations)
summarize_finite_result(result)
# Out:
#                 metric     value
# 0       log_likelihood -40.58515
# 1        viterbi_score -45.10777
# 2      n_active_states   1.00000
# 3           n_segments   1.00000
# 4  mean_segment_length  16.00000

# %%
from src.analysis.visualization import generate_finite_figures

generate_finite_figures(result, OUTPUT_DIR)
# Out:
# [PosixPath('/home/janusadamuz/Documentos/Melodies/outputs/notebook_finite/finite_transition_heatmap.png'),
#  PosixPath('/home/janusadamuz/Documentos/Melodies/outputs/notebook_finite/finite_emission_heatmap.png'),
#  PosixPath('/home/janusadamuz/Documentos/Melodies/outputs/notebook_finite/finite_transition_graph.png'),
#  PosixPath('/home/janusadamuz/Documentos/Melodies/outputs/notebook_finite/finite_timeline.png')]
